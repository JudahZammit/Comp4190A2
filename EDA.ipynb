# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
KEY = 'Left'

# %%
gyro = pd.read_csv('./q2/myo_keyboard_data/'+KEY+'/gyro.csv',index_col = 'timestamp')
acc = pd.read_csv('./q2/myo_keyboard_data/'+KEY+'/acc.csv',index_col = 'timestamp')
orin = pd.read_csv('./q2/myo_keyboard_data/'+KEY+'/orin.csv',index_col = 'timestamp')
eul = pd.read_csv('./q2/myo_keyboard_data/'+KEY+'/eul.csv',index_col = 'timestamp')
emg = pd.read_csv('./q2/myo_keyboard_data/'+KEY+'/emg.csv',index_col = 'timestamp')

# %%
MIN_TIMESTAMP = acc.index[0]

# %%
gyro.index = gyro.index - MIN_TIMESTAMP
acc.index = acc.index - MIN_TIMESTAMP
orin.index = orin.index - MIN_TIMESTAMP
eul.index = eul.index - MIN_TIMESTAMP
emg.index = emg.index - MIN_TIMESTAMP

# %%
gyro.head()
# Out:
#                 x       y      z
# timestamp
# 0          0.0625  0.0625  0.125
# 23001     -1.0625 -0.3750  0.125
# 39010     -0.4375  0.0000  0.125
# 60013      1.0625  0.1250  0.375
# 84224     -1.4375 -0.6250  0.375

# %%
emg.head()
# Out:
#            emg1  emg2  emg3  emg4  emg5  emg6  emg7  emg8
# timestamp
# 182050        1    -6     7     1    -2    -3    -2    -1
# 182050        3    -3     9     0    -4     0    -8     1
# 183050       -3    -7     6     7     0    -1     5    -5
# 183050        0     1     1   -40    -7    -3    -4    -3
# 184050       -3     2    12     5    -1    -2    -1    -4

# %%
emg.plot()

# %%
gyro.plot()

# %%
acc.plot()

# %%
eul.plot()

# %%
orin.plot()

# %%
emg['emg1'].plot()

# %%
emg['emg2'].plot()

# %%
emg['emg3'].plot()

# %%
emg['emg4'].plot()

# %%
emg['emg5'].plot()

# %%
emg['emg6'].plot()

# %%
emg['emg7'].plot()

# %%
emg['emg8'].plot()

# %%
avg_physical_update = (acc.index[-1] - acc.index[0])/len(acc.index)
avg_physical_update
# Out:
# 20005.740168539327

# %%
avg_emg_update = (emg.index[-1] - emg.index[0])/len(emg.index)/.5
avg_emg_update
# Out:
# 9999.269367448473

# %% [markdown]
# # Observations
# 1. The physical data starts earlier then the emg data
# 2. The emg data has two readings per timestamp
# 3. The physical data updates about every 20,000 timestamps
# 4. Ignoring the duplicates, the emg data updates about every 10,000 timestamps
# 5. The emg data is always active
# 6. The orintation data is often completly still
# 7. There seems to be some noise at the begining of each reading, this is probably when the subject initialy moves their hand to the keyboard
# 8. There seems to be some noise at the end of Left data
