# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
gyro = pd.read_csv('./q2/myo_keyboard_data/Backward/gyro-1456704054.csv',index_col = 'timestamp')
acc = pd.read_csv('./q2/myo_keyboard_data/Backward/accelerometer-1456704054.csv',index_col = 'timestamp')
orin = pd.read_csv('./q2/myo_keyboard_data/Backward/orientation-1456704054.csv',index_col = 'timestamp')
eul = pd.read_csv('./q2/myo_keyboard_data/Backward/orientationEuler-1456704054.csv',index_col = 'timestamp')
emg = pd.read_csv('./q2/myo_keyboard_data/Backward/emg-1456704054.csv',index_col = 'timestamp')

# %%
gyro = pd.read_csv('./q2/myo_keyboard_data/Forward/gyro-1456703940.csv',index_col = 'timestamp')
acc = pd.read_csv('./q2/myo_keyboard_data/Forward/accelerometer-1456703940.csv',index_col = 'timestamp')
orin = pd.read_csv('./q2/myo_keyboard_data/Forward/orientation-1456703940.csv',index_col = 'timestamp')
eul = pd.read_csv('./q2/myo_keyboard_data/Forward/orientationEuler-1456703940.csv',index_col = 'timestamp')
emg = pd.read_csv('./q2/myo_keyboard_data/Forward/emg-1456703940.csv',index_col = 'timestamp')

# %%
gyro = pd.read_csv('./q2/myo_keyboard_data/Enter/gyro-1456704184.csv',index_col = 'timestamp')
acc = pd.read_csv('./q2/myo_keyboard_data/Enter/accelerometer-1456704184.csv',index_col = 'timestamp')
orin = pd.read_csv('./q2/myo_keyboard_data/Enter/orientation-1456704184.csv',index_col = 'timestamp')
eul = pd.read_csv('./q2/myo_keyboard_data/Forward/orientationEuler-1456703940.csv',index_col = 'timestamp')
emg = pd.read_csv('./q2/myo_keyboard_data/Forward/emg-1456703940.csv',index_col = 'timestamp')

# %%
MIN_TIMESTAMP = acc.index[0]

# %%
gyro.index = gyro.index - MIN_TIMESTAMP
acc.index = acc.index - MIN_TIMESTAMP
orin.index = orin.index - MIN_TIMESTAMP
eul.index = eul.index - MIN_TIMESTAMP
emg.index = emg.index - MIN_TIMESTAMP

# %%
gyro.head()
# Out:
#                 x       y       z
# timestamp
# 0         -2.4375 -0.0625  0.6250
# 15999     -1.8125 -0.0625  0.8750
# 38545     -1.1875 -0.3125  0.6250
# 62020     -2.1875  0.0000  0.6250
# 77020     -0.1250 -0.3750  0.5625

# %%
emg.head()
# Out:
#            emg1  emg2  emg3  emg4  emg5  emg6  emg7  emg8
# timestamp
# 178244       -2    -1   -10   -10    -4    -2    -1    -2
# 178244        2    -2     3    11     7     2     0    -2
# 179245        1     2    -6    -7     7     4    -1    -1
# 179245       -3    -2    -3   -23   -20    -3     0     1
# 182245       -1    -1    12    40     8    -1    -2    -1

# %%
emg.plot()

# %%
gyro.plot()

# %%
acc.plot()

# %%
eul.plot()

# %%
orin.plot()

# %%
gyro.iloc[0:5].plot()

# %%
emg.iloc[0:5].plot()
